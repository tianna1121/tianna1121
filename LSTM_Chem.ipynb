# %% [markdown]
# <a href="https://colab.research.google.com/github/tianna1121/tianna1121/blob/master/LSTM_Chem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### install conda 
# !wget https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh && bash Anaconda3-5.2.0-Linux-x86_64.sh -bfp /usr/local
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages')
# Out:
# --2020-02-27 02:41:59--  https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 651745206 (622M) [application/x-sh]
# Saving to: ‘Anaconda3-5.2.0-Linux-x86_64.sh’
#
# Anaconda3-5.2.0-Lin 100%[===================>] 621.55M  83.6MB/s    in 7.2s
#
# 2020-02-27 02:42:06 (86.4 MB/s) - ‘Anaconda3-5.2.0-Linux-x86_64.sh’ saved [651745206/651745206]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: blas-1.0-mkl ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: intel-openmp-2018.0.0-8 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libgfortran-ng-7.2.0-hdf63c60_3 ...
# ...

# %%
# install dependencies of LSTM_Chem
# !conda install -c rdkit rdkit-postgresql -y
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit-postgresql
#
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.03.07-0            --> 2020.1.1-0
#     cairo:           1.14.12-h7636065_2      --> 1.14.12-h8948797_3
#     certifi:         2018.4.16-py36_0        --> 2019.11.28-py36_0
#     conda:           4.5.4-py36_0            --> 4.8.2-py36_0
#     cryptography:    2.2.2-py36h14c3975_0    --> 2.8-py36h1ba5d50_0
#     curl:            7.60.0-h84994c4_0       --> 7.67.0-hbc83047_0
#     expat:           2.2.5-he0dffb1_0        --> 2.2.6-he6710b0_0
#     fontconfig:      2.12.6-h49f89f6_0       --> 2.13.0-h9420a91_0
#     freetype:        2.8-hab7d2ae_1          --> 2.9.1-h8a8886c_1
#     glib:            2.56.1-h000015b_0       --> 2.56.2-hd408876_0
#     harfbuzz:        1.7.6-h5f0a787_1        --> 1.8.8-hffaf4a1_0
#     libcurl:         7.60.0-h1ad7b7a_0       --> 7.67.0-h20c2e04_0
# ...

# %%
# !conda install numpy anaconda tensorflow-gpu tqdm -y
# Out:
# done
# /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::bottleneck==1.2.1=py36haac1ea0_0
#   - defaults/linux-64::pytest-astropy==0.3.0=py36_0
#   - defaults/linux-64::bkcharts==0.2=py36h735825a_0
#   - defaults/linux-64::mkl_random==1.0.1=py36h629b387_0
#   - defaults/linux-64::patsy==0.5.0=py36_0
#   - defaults/linux-64::pywavelets==0.5.2=py36he602eb0_0
#   - defaults/linux-64::odo==0.5.1=py36h90ed295_0
#   - defaults/linux-64::numpy-base==1.14.3=py36h9be14a7_1
#   - defaults/linux-64::datashape==0.5.4=py36h3ad6b5c_0
#   - defaults/linux-64::blaze==0.11.3=py36h4e06776_0
#   - defaults/linux-64::statsmodels==0.9.0=py36h3010b51_0
#   - defaults/linux-64::pytables==3.4.3=py36h02b9ad4_2
#   - defaults/linux-64::numba==0.38.0=py36h637b7d7_0
#   - defaults/linux-64::numexpr==2.6.5=py36h7bf3b9c_0
#   - defaults/linux-64::anaconda==5.2.0=py36_3
# ...

# %%
# !conda install -c conda-forge matplotlib bunch -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bunch
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bunch-1.0.1                |             py_1           8 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     conda-4.8.2                |           py36_0         3.0 MB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   bunch              conda-forge/noarch::bunch-1.0.1-py_1
#
# ...

# %%
# !conda install -c intel scikit-learn -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.1.18          |     py36_intel_0         143 KB  intel
#     daal-2018.0.3.20180405     |                0        59.7 MB  intel
#     intelpython-2018.0.3       |                0           4 KB  intel
#     openssl-1.1.1d             |                0         3.6 MB  intel
#     pydaal-2018.0.3.20180405   |np114py36_intel_0       192.3 MB  intel
#     scikit-learn-0.19.1        |np114py36_intel_29         6.3 MB  intel
#     ------------------------------------------------------------
#                                            Total:       262.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   daal               intel/linux-64::daal-2018.0.3.20180405-0
# ...

# %%
## https://github.com/topazape/LSTM_Chem
# !git clone https://github.com/topazape/LSTM_Chem
# %cd LSTM_Chem
# Out:
# fatal: destination path 'LSTM_Chem' already exists and is not an empty directory.
# /content/LSTM_Chem

# %%
# !python3 train.py
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory
